# %%
# %matplotlib inline
from sklearn.datasets import load_diabetes
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
diabetes = load_diabetes()
X = diabetes.data
y = diabetes.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=11)
print(X_train.shape)
print(X_test.shape)
# Out:
# (331, 10)
# (111, 10)

# %%
X_train.shape
# Out:
# (331, 10)

# %%
X_test.shape
# Out:
# (111, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
linear_regression.coef_
# Out:
# array([ -60.22189333, -266.45890749,  523.0596748 ,  310.51485159,
#        -336.17030793,  137.34454454, -131.1356043 ,   -1.14855016,
#         622.33749249,   60.46751764])

# %%
linear_regression.intercept_
# Out:
# 152.22835839334243

# %%
predicted = linear_regression.predict(X_test)

# %%
expected = y_test

# %%
for p, e in zip(predicted[::5], expected[::5]):  # check every 5th element
    print(f'predicted: {p:.2f}, expected: {e:.2f}')
# Out:
# predicted: 115.47, expected: 79.00
# predicted: 230.56, expected: 321.00
# predicted: 160.21, expected: 95.00
# predicted: 82.26, expected: 60.00
# predicted: 53.86, expected: 57.00
# predicted: 154.51, expected: 134.00
# predicted: 186.20, expected: 232.00
# predicted: 126.68, expected: 68.00
# predicted: 86.45, expected: 42.00
# predicted: 165.97, expected: 151.00
# predicted: 175.28, expected: 107.00
# predicted: 113.97, expected: 63.00
# predicted: 76.70, expected: 48.00
# predicted: 102.98, expected: 118.00
# predicted: 190.73, expected: 202.00
# predicted: 241.49, expected: 306.00
# predicted: 234.02, expected: 152.00
# predicted: 251.54, expected: 233.00
# predicted: 104.54, expected: 135.00
# predicted: 59.17, expected: 77.00
# predicted: 153.66, expected: 262.00
# predicted: 226.28, expected: 275.00
# predicted: 83.05, expected: 42.00

# %%
# lambda kullanarak tahmin fonksiyonu oluşturma
predict = lambda x: linear_regression.coef_ * x + linear_regression.intercept_

# %%
predict(2019)
# Out:
# array([-121435.77427868, -537828.30586468, 1056209.71178364,
#         627081.71372197, -678575.62334315,  277450.86378121,
#        -264610.55671702,   -2166.69441244, 1256651.62569687,
#         122236.14646555])

# %%
predict(1890)
# Out:
# array([-113667.15003887, -503455.10679842,  988735.01373418,
#         587025.29786665, -635209.65362076,  259733.41753577,
#        -247694.06376272,   -2018.53144194, 1176370.08916559,
#         114435.8366905 ])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
feature_index = 0 
axes = sns.scatterplot(x=diabetes.data[:, feature_index], y=diabetes.target, hue=diabetes.target, palette='winter', legend=False)
axes.set_ylim(min(y) - 10, max(y) + 10)  # y ekseni ölçeği ayarlama
# Out:
# (15.0, 356.0)

# %%
x = np.linspace(min(X[:, feature_index]), max(X[:, feature_index]), 100)
y = linear_regression.coef_[feature_index] * x + linear_regression.intercept_
plt.plot(x, y, color='red')
plt.show()
